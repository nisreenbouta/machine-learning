# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_csv("/kaggle/input/bankadditionalfullcsv/bank-additional-full.csv",sep=";")

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41183  nonexistent         -1.1          94.767          -50.8      1.028
# 41184  nonexistent         -1.1          94.767          -50.8      1.028
# 41185  nonexistent         -1.1          94.767          -50.8      1.028
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
def return_categorical(data):
    categorical_columns= [column_name for column_name in data if data[column_name].dtype=="0"]
    return categorical_columns
def return_numerical(data):
    return list(set(data.columns) - set (return_categorical(data)))
def check_normal(data):
    fig, axes = plt.subplots(1, len(return_numerical(data)))
    for i, numeric_column_name in enumerate(set(data.columns).difference(return_categorical(data))):
        sns. displot (data [numeric_column_name], ax=axes [1]);
        plt.title(f'Distribution of {numeric_column_name}');
def classifler(clf,x_train, x_test, y_train, y_test):
    y_test_pred = clf.predict (x_test)
    y_train_pred = clf.predict(x_train)
                          
    accuracy_test = accuracy_score (y_test,y_test_pred)
    accuracy_train = accuracy_score(y_train,y_train_pred)
                          
    roc_test = roc_auc_score(y_test, y_test_pred, multi_class='ovr')
    roc_train = roc_auc_score(y_train, y_train_pred, multi_class='ovr') 
    print ('Train accuracy Is:',accuracy_train )
    print('Test accuracy is:',accuracy_test )
    print()
    print('Train ROC is:', roc_train)
    print('Test ROC is:', roc_test )
    f1 = f1_score(y_test,y_test_pred)
    precision = precision_score(y_test,y_test_pred)
    recall = recall_score(y_test,y_test_pred)
    print()
    print("F1 score is:", f1)
    print("Precision is:",precision)
    print("Recall is:",recall)
def random_search(clf,params, x_train, x_test,y_train,y_test):
    random_search = RandomizedSearchCV(estimator= clf, param_distributions=params, scoring='roc_auc', cv=5)
    random_search.fit(x_train, y_train)
    optimal_model = random_search.best_estimator_
                          
    print("Best parameters are:",random_search.best_params_)
    print()
    print("Best estimator is:",random_search.best_estimator_)
    print()
    print("Scores and accuracies are:")
    print()
    classifier(optimal_model, x_train,x_test,y_train_y,test)

# %%
check_normal(data)

# %%
for col in return_categorical(data) :
    counts = data[col].value_counts().sort_index()
    if len(counts) > 10:
        fig = plt.figure(figsize=(30, 10))
    else:
        fig = plt.figure(figsize=(9, 6))
    ax = fig.gca()
    counts.plot.bar(ax= ax, color='steelblue') 
    ax.set_title(col + 'counts')
    ax.set_xlabel(col)
    ax.set_ylabel("Frequency")
plt.show()

# %%
corr = data.corr()
corr_greater_than_75 = corr[corr>.75]
corr_greater_than_75
# Out:
#                                age  duration  campaign  pdays  previous  \
# age                            1.0       NaN       NaN    NaN       NaN
# duration                       NaN       1.0       NaN    NaN       NaN
# campaign                       NaN       NaN       1.0    NaN       NaN
# pdays                          NaN       NaN       NaN    1.0       NaN
# previous                       NaN       NaN       NaN    NaN       1.0
# emp.var.rate                   NaN       NaN       NaN    NaN       NaN
# cons.price.idx                 NaN       NaN       NaN    NaN       NaN
# cons.conf.idx                  NaN       NaN       NaN    NaN       NaN
# euribor3m                      NaN       NaN       NaN    NaN       NaN
# nr.employed                    NaN       NaN       NaN    NaN       NaN
# job_blue-collar                NaN       NaN       NaN    NaN       NaN
# job_entrepreneur               NaN       NaN       NaN    NaN       NaN
# job_housemaid                  NaN       NaN       NaN    NaN       NaN
# job_management                 NaN       NaN       NaN    NaN       NaN
# job_retired                    NaN       NaN       NaN    NaN       NaN
# job_self-employed              NaN       NaN       NaN    NaN       NaN
# job_services                   NaN       NaN       NaN    NaN       NaN
# job_student                    NaN       NaN       NaN    NaN       NaN
# job_technician                 NaN       NaN       NaN    NaN       NaN
# job_unemployed                 NaN       NaN       NaN    NaN       NaN
# job_unknown                    NaN       NaN       NaN    NaN       NaN
# marital_married                NaN       NaN       NaN    NaN       NaN
# marital_single                 NaN       NaN       NaN    NaN       NaN
# marital_unknown                NaN       NaN       NaN    NaN       NaN
# education_basic.6y             NaN       NaN       NaN    NaN       NaN
# education_basic.9y             NaN       NaN       NaN    NaN       NaN
# education_high.school          NaN       NaN       NaN    NaN       NaN
# education_illiterate           NaN       NaN       NaN    NaN       NaN
# education_professional.course  NaN       NaN       NaN    NaN       NaN
# education_university.degree    NaN       NaN       NaN    NaN       NaN
# education_unknown              NaN       NaN       NaN    NaN       NaN
# default_unknown                NaN       NaN       NaN    NaN       NaN
# default_yes                    NaN       NaN       NaN    NaN       NaN
# housing_unknown                NaN       NaN       NaN    NaN       NaN
# housing_yes                    NaN       NaN       NaN    NaN       NaN
# loan_unknown                   NaN       NaN       NaN    NaN       NaN
# loan_yes                       NaN       NaN       NaN    NaN       NaN
# contact_telephone              NaN       NaN       NaN    NaN       NaN
# month_aug                      NaN       NaN       NaN    NaN       NaN
# month_dec                      NaN       NaN       NaN    NaN       NaN
# month_jul                      NaN       NaN       NaN    NaN       NaN
# month_jun                      NaN       NaN       NaN    NaN       NaN
# month_mar                      NaN       NaN       NaN    NaN       NaN
# month_may                      NaN       NaN       NaN    NaN       NaN
# month_nov                      NaN       NaN       NaN    NaN       NaN
# month_oct                      NaN       NaN       NaN    NaN       NaN
# month_sep                      NaN       NaN       NaN    NaN       NaN
# day_of_week_mon                NaN       NaN       NaN    NaN       NaN
# day_of_week_thu                NaN       NaN       NaN    NaN       NaN
# day_of_week_tue                NaN       NaN       NaN    NaN       NaN
# day_of_week_wed                NaN       NaN       NaN    NaN       NaN
# poutcome_nonexistent           NaN       NaN       NaN    NaN       NaN
# poutcome_success               NaN       NaN       NaN    NaN       NaN
# y_yes                          NaN       NaN       NaN    NaN       NaN
#
#                                emp.var.rate  cons.price.idx  cons.conf.idx  \
# age                                     NaN             NaN            NaN
# duration                                NaN             NaN            NaN
# campaign                                NaN             NaN            NaN
# pdays                                   NaN             NaN            NaN
# previous                                NaN             NaN            NaN
# emp.var.rate                       1.000000        0.775334            NaN
# cons.price.idx                     0.775334        1.000000            NaN
# cons.conf.idx                           NaN             NaN            1.0
# euribor3m                          0.972245             NaN            NaN
# nr.employed                        0.906970             NaN            NaN
# job_blue-collar                         NaN             NaN            NaN
# job_entrepreneur                        NaN             NaN            NaN
# job_housemaid                           NaN             NaN            NaN
# job_management                          NaN             NaN            NaN
# job_retired                             NaN             NaN            NaN
# job_self-employed                       NaN             NaN            NaN
# job_services                            NaN             NaN            NaN
# job_student                             NaN             NaN            NaN
# job_technician                          NaN             NaN            NaN
# job_unemployed                          NaN             NaN            NaN
# job_unknown                             NaN             NaN            NaN
# marital_married                         NaN             NaN            NaN
# marital_single                          NaN             NaN            NaN
# marital_unknown                         NaN             NaN            NaN
# education_basic.6y                      NaN             NaN            NaN
# education_basic.9y                      NaN             NaN            NaN
# education_high.school                   NaN             NaN            NaN
# education_illiterate                    NaN             NaN            NaN
# education_professional.course           NaN             NaN            NaN
# education_university.degree             NaN             NaN            NaN
# education_unknown                       NaN             NaN            NaN
# default_unknown                         NaN             NaN            NaN
# default_yes                             NaN             NaN            NaN
# housing_unknown                         NaN             NaN            NaN
# housing_yes                             NaN             NaN            NaN
# loan_unknown                            NaN             NaN            NaN
# loan_yes                                NaN             NaN            NaN
# contact_telephone                       NaN             NaN            NaN
# month_aug                               NaN             NaN            NaN
# month_dec                               NaN             NaN            NaN
# month_jul                               NaN             NaN            NaN
# month_jun                               NaN             NaN            NaN
# month_mar                               NaN             NaN            NaN
# month_may                               NaN             NaN            NaN
# month_nov                               NaN             NaN            NaN
# month_oct                               NaN             NaN            NaN
# month_sep                               NaN             NaN            NaN
# day_of_week_mon                         NaN             NaN            NaN
# day_of_week_thu                         NaN             NaN            NaN
# day_of_week_tue                         NaN             NaN            NaN
# day_of_week_wed                         NaN             NaN            NaN
# poutcome_nonexistent                    NaN             NaN            NaN
# poutcome_success                        NaN             NaN            NaN
# y_yes                                   NaN             NaN            NaN
#
#                                euribor3m  nr.employed  ...  month_nov  \
# age                                  NaN          NaN  ...        NaN
# duration                             NaN          NaN  ...        NaN
# campaign                             NaN          NaN  ...        NaN
# pdays                                NaN          NaN  ...        NaN
# previous                             NaN          NaN  ...        NaN
# emp.var.rate                    0.972245     0.906970  ...        NaN
# cons.price.idx                       NaN          NaN  ...        NaN
# cons.conf.idx                        NaN          NaN  ...        NaN
# euribor3m                       1.000000     0.945154  ...        NaN
# nr.employed                     0.945154     1.000000  ...        NaN
# job_blue-collar                      NaN          NaN  ...        NaN
# job_entrepreneur                     NaN          NaN  ...        NaN
# job_housemaid                        NaN          NaN  ...        NaN
# job_management                       NaN          NaN  ...        NaN
# job_retired                          NaN          NaN  ...        NaN
# job_self-employed                    NaN          NaN  ...        NaN
# job_services                         NaN          NaN  ...        NaN
# job_student                          NaN          NaN  ...        NaN
# job_technician                       NaN          NaN  ...        NaN
# job_unemployed                       NaN          NaN  ...        NaN
# job_unknown                          NaN          NaN  ...        NaN
# marital_married                      NaN          NaN  ...        NaN
# marital_single                       NaN          NaN  ...        NaN
# marital_unknown                      NaN          NaN  ...        NaN
# education_basic.6y                   NaN          NaN  ...        NaN
# education_basic.9y                   NaN          NaN  ...        NaN
# education_high.school                NaN          NaN  ...        NaN
# education_illiterate                 NaN          NaN  ...        NaN
# education_professional.course        NaN          NaN  ...        NaN
# education_university.degree          NaN          NaN  ...        NaN
# education_unknown                    NaN          NaN  ...        NaN
# default_unknown                      NaN          NaN  ...        NaN
# default_yes                          NaN          NaN  ...        NaN
# housing_unknown                      NaN          NaN  ...        NaN
# housing_yes                          NaN          NaN  ...        NaN
# loan_unknown                         NaN          NaN  ...        NaN
# loan_yes                             NaN          NaN  ...        NaN
# contact_telephone                    NaN          NaN  ...        NaN
# month_aug                            NaN          NaN  ...        NaN
# month_dec                            NaN          NaN  ...        NaN
# month_jul                            NaN          NaN  ...        NaN
# month_jun                            NaN          NaN  ...        NaN
# month_mar                            NaN          NaN  ...        NaN
# month_may                            NaN          NaN  ...        NaN
# month_nov                            NaN          NaN  ...        1.0
# month_oct                            NaN          NaN  ...        NaN
# month_sep                            NaN          NaN  ...        NaN
# day_of_week_mon                      NaN          NaN  ...        NaN
# day_of_week_thu                      NaN          NaN  ...        NaN
# day_of_week_tue                      NaN          NaN  ...        NaN
# day_of_week_wed                      NaN          NaN  ...        NaN
# poutcome_nonexistent                 NaN          NaN  ...        NaN
# poutcome_success                     NaN          NaN  ...        NaN
# y_yes                                NaN          NaN  ...        NaN
#
#                                month_oct  month_sep  day_of_week_mon  \
# age                                  NaN        NaN              NaN
# duration                             NaN        NaN              NaN
# campaign                             NaN        NaN              NaN
# pdays                                NaN        NaN              NaN
# previous                             NaN        NaN              NaN
# emp.var.rate                         NaN        NaN              NaN
# cons.price.idx                       NaN        NaN              NaN
# cons.conf.idx                        NaN        NaN              NaN
# euribor3m                            NaN        NaN              NaN
# nr.employed                          NaN        NaN              NaN
# job_blue-collar                      NaN        NaN              NaN
# job_entrepreneur                     NaN        NaN              NaN
# job_housemaid                        NaN        NaN              NaN
# job_management                       NaN        NaN              NaN
# job_retired                          NaN        NaN              NaN
# job_self-employed                    NaN        NaN              NaN
# job_services                         NaN        NaN              NaN
# job_student                          NaN        NaN              NaN
# job_technician                       NaN        NaN              NaN
# job_unemployed                       NaN        NaN              NaN
# job_unknown                          NaN        NaN              NaN
# marital_married                      NaN        NaN              NaN
# marital_single                       NaN        NaN              NaN
# marital_unknown                      NaN        NaN              NaN
# education_basic.6y                   NaN        NaN              NaN
# education_basic.9y                   NaN        NaN              NaN
# education_high.school                NaN        NaN              NaN
# education_illiterate                 NaN        NaN              NaN
# education_professional.course        NaN        NaN              NaN
# education_university.degree          NaN        NaN              NaN
# education_unknown                    NaN        NaN              NaN
# default_unknown                      NaN        NaN              NaN
# default_yes                          NaN        NaN              NaN
# housing_unknown                      NaN        NaN              NaN
# housing_yes                          NaN        NaN              NaN
# loan_unknown                         NaN        NaN              NaN
# loan_yes                             NaN        NaN              NaN
# contact_telephone                    NaN        NaN              NaN
# month_aug                            NaN        NaN              NaN
# month_dec                            NaN        NaN              NaN
# month_jul                            NaN        NaN              NaN
# month_jun                            NaN        NaN              NaN
# month_mar                            NaN        NaN              NaN
# month_may                            NaN        NaN              NaN
# month_nov                            NaN        NaN              NaN
# month_oct                            1.0        NaN              NaN
# month_sep                            NaN        1.0              NaN
# day_of_week_mon                      NaN        NaN              1.0
# day_of_week_thu                      NaN        NaN              NaN
# day_of_week_tue                      NaN        NaN              NaN
# day_of_week_wed                      NaN        NaN              NaN
# poutcome_nonexistent                 NaN        NaN              NaN
# poutcome_success                     NaN        NaN              NaN
# y_yes                                NaN        NaN              NaN
#
#                                day_of_week_thu  day_of_week_tue  \
# age                                        NaN              NaN
# duration                                   NaN              NaN
# campaign                                   NaN              NaN
# pdays                                      NaN              NaN
# previous                                   NaN              NaN
# emp.var.rate                               NaN              NaN
# cons.price.idx                             NaN              NaN
# cons.conf.idx                              NaN              NaN
# euribor3m                                  NaN              NaN
# nr.employed                                NaN              NaN
# job_blue-collar                            NaN              NaN
# job_entrepreneur                           NaN              NaN
# job_housemaid                              NaN              NaN
# job_management                             NaN              NaN
# job_retired                                NaN              NaN
# job_self-employed                          NaN              NaN
# job_services                               NaN              NaN
# job_student                                NaN              NaN
# job_technician                             NaN              NaN
# job_unemployed                             NaN              NaN
# job_unknown                                NaN              NaN
# marital_married                            NaN              NaN
# marital_single                             NaN              NaN
# marital_unknown                            NaN              NaN
# education_basic.6y                         NaN              NaN
# education_basic.9y                         NaN              NaN
# education_high.school                      NaN              NaN
# education_illiterate                       NaN              NaN
# education_professional.course              NaN              NaN
# education_university.degree                NaN              NaN
# education_unknown                          NaN              NaN
# default_unknown                            NaN              NaN
# default_yes                                NaN              NaN
# housing_unknown                            NaN              NaN
# housing_yes                                NaN              NaN
# loan_unknown                               NaN              NaN
# loan_yes                                   NaN              NaN
# contact_telephone                          NaN              NaN
# month_aug                                  NaN              NaN
# month_dec                                  NaN              NaN
# month_jul                                  NaN              NaN
# month_jun                                  NaN              NaN
# month_mar                                  NaN              NaN
# month_may                                  NaN              NaN
# month_nov                                  NaN              NaN
# month_oct                                  NaN              NaN
# month_sep                                  NaN              NaN
# day_of_week_mon                            NaN              NaN
# day_of_week_thu                            1.0              NaN
# day_of_week_tue                            NaN              1.0
# day_of_week_wed                            NaN              NaN
# poutcome_nonexistent                       NaN              NaN
# poutcome_success                           NaN              NaN
# y_yes                                      NaN              NaN
#
#                                day_of_week_wed  poutcome_nonexistent  \
# age                                        NaN                   NaN
# duration                                   NaN                   NaN
# campaign                                   NaN                   NaN
# pdays                                      NaN                   NaN
# previous                                   NaN                   NaN
# emp.var.rate                               NaN                   NaN
# cons.price.idx                             NaN                   NaN
# cons.conf.idx                              NaN                   NaN
# euribor3m                                  NaN                   NaN
# nr.employed                                NaN                   NaN
# job_blue-collar                            NaN                   NaN
# job_entrepreneur                           NaN                   NaN
# job_housemaid                              NaN                   NaN
# job_management                             NaN                   NaN
# job_retired                                NaN                   NaN
# job_self-employed                          NaN                   NaN
# job_services                               NaN                   NaN
# job_student                                NaN                   NaN
# job_technician                             NaN                   NaN
# job_unemployed                             NaN                   NaN
# job_unknown                                NaN                   NaN
# marital_married                            NaN                   NaN
# marital_single                             NaN                   NaN
# marital_unknown                            NaN                   NaN
# education_basic.6y                         NaN                   NaN
# education_basic.9y                         NaN                   NaN
# education_high.school                      NaN                   NaN
# education_illiterate                       NaN                   NaN
# education_professional.course              NaN                   NaN
# education_university.degree                NaN                   NaN
# education_unknown                          NaN                   NaN
# default_unknown                            NaN                   NaN
# default_yes                                NaN                   NaN
# housing_unknown                            NaN                   NaN
# housing_yes                                NaN                   NaN
# loan_unknown                               NaN                   NaN
# loan_yes                                   NaN                   NaN
# contact_telephone                          NaN                   NaN
# month_aug                                  NaN                   NaN
# month_dec                                  NaN                   NaN
# month_jul                                  NaN                   NaN
# month_jun                                  NaN                   NaN
# month_mar                                  NaN                   NaN
# month_may                                  NaN                   NaN
# month_nov                                  NaN                   NaN
# month_oct                                  NaN                   NaN
# month_sep                                  NaN                   NaN
# day_of_week_mon                            NaN                   NaN
# day_of_week_thu                            NaN                   NaN
# day_of_week_tue                            NaN                   NaN
# day_of_week_wed                            1.0                   NaN
# poutcome_nonexistent                       NaN                   1.0
# poutcome_success                           NaN                   NaN
# y_yes                                      NaN                   NaN
#
#                                poutcome_success  y_yes
# age                                         NaN    NaN
# duration                                    NaN    NaN
# campaign                                    NaN    NaN
# pdays                                       NaN    NaN
# previous                                    NaN    NaN
# emp.var.rate                                NaN    NaN
# cons.price.idx                              NaN    NaN
# cons.conf.idx                               NaN    NaN
# euribor3m                                   NaN    NaN
# nr.employed                                 NaN    NaN
# job_blue-collar                             NaN    NaN
# job_entrepreneur                            NaN    NaN
# job_housemaid                               NaN    NaN
# job_management                              NaN    NaN
# job_retired                                 NaN    NaN
# job_self-employed                           NaN    NaN
# job_services                                NaN    NaN
# job_student                                 NaN    NaN
# job_technician                              NaN    NaN
# job_unemployed                              NaN    NaN
# job_unknown                                 NaN    NaN
# marital_married                             NaN    NaN
# marital_single                              NaN    NaN
# marital_unknown                             NaN    NaN
# education_basic.6y                          NaN    NaN
# education_basic.9y                          NaN    NaN
# education_high.school                       NaN    NaN
# education_illiterate                        NaN    NaN
# education_professional.course               NaN    NaN
# education_university.degree                 NaN    NaN
# education_unknown                           NaN    NaN
# default_unknown                             NaN    NaN
# default_yes                                 NaN    NaN
# housing_unknown                             NaN    NaN
# housing_yes                                 NaN    NaN
# loan_unknown                                NaN    NaN
# loan_yes                                    NaN    NaN
# contact_telephone                           NaN    NaN
# month_aug                                   NaN    NaN
# month_dec                                   NaN    NaN
# month_jul                                   NaN    NaN
# month_jun                                   NaN    NaN
# month_mar                                   NaN    NaN
# month_may                                   NaN    NaN
# month_nov                                   NaN    NaN
# month_oct                                   NaN    NaN
# month_sep                                   NaN    NaN
# day_of_week_mon                             NaN    NaN
# day_of_week_thu                             NaN    NaN
# day_of_week_tue                             NaN    NaN
# day_of_week_wed                             NaN    NaN
# poutcome_nonexistent                        NaN    NaN
# poutcome_success                            1.0    NaN
# y_yes                                       NaN    1.0
#
# [54 rows x 54 columns]

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr_greater_than_75,cmap="Reds", annot= True);

# %%
data = pd.get_dummies(data, drop_first = True)
