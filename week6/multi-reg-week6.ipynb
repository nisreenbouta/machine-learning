# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv("/kaggle/input/addvertise/AD.csv")

# %%
df.head()
# Out:
#       tv  radio  newspaper  sales
# 0   55.7   20.4       30.8   33.3
# 1  314.2   34.1       80.4   16.9
# 2  103.8   22.8       79.6   29.7
# 3  263.7   13.4       99.3   31.2
# 4   98.4   30.6       65.1   15.3

# %%
x = df[["tv", "radio", "newspaper"]]
y= df["sales"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.linear_model import LinearRegression
mlr= LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("intercept:", mlr.intercept_)
print("coefficiants:")
list(zip(x,mlr.coef_))
# Out:
# intercept: 50.81440741251079
# coefficiants:
# [('tv', 0.18521188308366365),
#  ('radio', -0.4061885798396587),
#  ('newspaper', -0.6345604633617471)]

# %%
y_pred = mlr.predict(x_test)
print("prediction for test set:{}".format(y_pred))
# Out:
# prediction for test set:[44.13828925 10.26728837]

# %%
mlr_dif = pd.DataFrame({"actual value: ":y_test,"predited value: ":y_pred})
mlr_dif.head()
# Out:
#    actual value:   predited value:
# 1            16.9         44.138289
# 2            29.7         10.267288

# %%
from sklearn import metrics
meansquare = metrics.mean_squared_error(y_test,y_pred)
print("r squared: {:.2f}".format(mlr.score(x,y)*100))
print("mse: ", meansquare)
# Out:
# r squared: -287.75
# mse:  559.7773412449199
