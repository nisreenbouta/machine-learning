# %% [markdown]
# # **Linear Regression**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/kaggle/input/agesalary/salarydata.csv")

# %%
df
# Out:
#     age  salary
# 0    55   90000
# 1    22   50000
# 2    34   60000
# 3    41   75000
# 4    44   75555
# 5    52   88888
# 6    36   65000
# 7    33   60000
# 8    22   50000
# 9    28   55000
# 10   60  100000
# 11   56   90000
# 12   46   79000
# 13   43   75000
# 14   24   50000
# 15   27   55000
# 16   23   50000
# 17   21   45000
# 18   26   55000
# 19   32   60000
# 20   30   60000
# 21   39   65000
# 22   40   70000
# 23   48   77000
# 24   35   65500
# 25   31   60000
# 26   52   90000
# 27   64  110000

# %%
df.head()
# Out:
#    age  salary
# 0   55   90000
# 1   22   50000
# 2   34   60000
# 3   41   75000
# 4   44   75555

# %%
plt.scatter(df.age,df.salary) 
plt.xlabel("Age") 
plt.ylabel("Salary")    
plt.show()

# %%
x = df.age.values

# %%
x.shape
# Out:
# (28,)

# %%
x = df.age.values.reshape(-1,1)
y = df.salary.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression() 
linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
#prediction
import numpy as np

b0 = linear_reg.predict([[0]]) 
print("b0: ",b0)
# Out:
# b0:  [[17879.06340691]]

# %%
b0_ = linear_reg.intercept_   
print("b0: ",b0_)
# Out:
# b0:  [17879.06340691]

# %%
b1 = linear_reg.coef_  
print("b1: ",b1)
# Out:
# b1:  [[1339.59513591]]

# %%
new_salary = 1663 + 1138*11 
print(new_salary)
# Out:
# 14181

# %%
b11 = linear_reg.predict([[11]]) 
print("b11: ",b11)
# Out:
# b11:  [[14185.72536421]]

# %%
y_head = linear_reg.predict(x)

# %%
plt.plot(x, y_head, color="orange")
plt.scatter(x,y)
plt.show()

# %%
from sklearn.metrics import r2_score
print("R Square Score: ",r2_score(y,y_head))
# Out:
# R Square Score:  0.9778801815139985

# %%
from sklearn.metrics import mean_squared_error
print("Mean Squared Error: ",mean_squared_error(y,y_head))
# Out:
# Mean Squared Error:  6080137.951711257

# %%
MSE = np.square(np.subtract(y,y_head)).mean()
print("Mean Squared Error: ",MSE)
# Out:
# Mean Squared Error:  6080137.951711257
