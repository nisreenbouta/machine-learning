# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("/kaggle/input/randomforestregressiondataset/random-forest-regression-dataset.csv", header=None)

# %%
df
# Out:
#     0    1
# 0   1  100
# 1   2   80
# 2   3   70
# 3   4   60
# 4   5   50
# 5   6   40
# 6   7   30
# 7   8   20
# 8   9   10
# 9  10    5

# %%
x=df.iloc[:,0].values.reshape(-1,1)
y=df.iloc[:,1].values.reshape(-1,1)

# %%
from sklearn.ensemble import RandomForestRegressor
rf= RandomForestRegressor(n_estimators=100, random_state=42)

# %%
rf.fit(x,y)
# Out:
# /tmp/ipykernel_35/2439990766.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(x,y)
# RandomForestRegressor(random_state=42)

# %%
rf.predict([[7.8]])
# Out:
# array([22.7])

# %%
x_= np.arange(min(x), max(x),0.01).reshape(-1,1)

# %%
y_head= rf.predict(x_)
plt.scatter(x,y,color="yellow")
plt.plot(x_,y_head,color="blue")
plt.xlabel("tribun level")
plt.ylabel("price")
plt.show()
